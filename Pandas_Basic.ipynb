# %% [markdown]
# https://medium.com/@aspershupadhyay/data-wrangling-like-a-pro-15-advanced-pandas-functions-for-data-analysis-687608fed8ba

# %%
import pandas as pd

# %%
pandas_df = pd.read_csv('penguins.csv')
pandas_df
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h1>1.apply()</h1>

# %%
pandas_df['bill_length_mm'] = pandas_df['bill_length_mm'].apply(lambda x:x/10)
pandas_df
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen           0.391           18.7
# 1        2     Adelie  Torgersen           0.395           17.4
# 2        3     Adelie  Torgersen           0.403           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen           0.367           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream           0.558           19.8
# 340    341  Chinstrap      Dream           0.435           18.1
# 341    342  Chinstrap      Dream           0.496           18.2
# 342    343  Chinstrap      Dream           0.508           19.0
# 343    344  Chinstrap      Dream           0.502           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h1>2. nunique()</h1>

# %%
pandas_df['species'].nunique()
# Out:
# 3

# %% [markdown]
# <h1>3. sortvalues()</h1>

# %%
pandas_df.sort_values("body_mass_g", ascending=False)
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 169    170     Gentoo     Biscoe           0.492           15.2
# 185    186     Gentoo     Biscoe           0.596           17.0
# 269    270     Gentoo     Biscoe           0.488           16.2
# 229    230     Gentoo     Biscoe           0.511           16.3
# 263    264     Gentoo     Biscoe           0.498           15.9
# ..     ...        ...        ...             ...            ...
# 58      59     Adelie     Biscoe           0.365           16.6
# 64      65     Adelie     Biscoe           0.364           17.1
# 314    315  Chinstrap      Dream           0.469           16.6
# 3        4     Adelie  Torgersen             NaN            NaN
# 271    272     Gentoo     Biscoe             NaN            NaN
#
#      flipper_length_mm  body_mass_g     sex  year
# 169              221.0       6300.0    male  2007
# 185              230.0       6050.0    male  2007
# ...

# %%
pandas_df = pandas_df.rename(columns={'species':'penguin_species'})
pandas_df
# Out:
#      rowid penguin_species     island  bill_length_mm  bill_depth_mm  \
# 0        1          Adelie  Torgersen           0.391           18.7
# 1        2          Adelie  Torgersen           0.395           17.4
# 2        3          Adelie  Torgersen           0.403           18.0
# 3        4          Adelie  Torgersen             NaN            NaN
# 4        5          Adelie  Torgersen           0.367           19.3
# ..     ...             ...        ...             ...            ...
# 339    340       Chinstrap      Dream           0.558           19.8
# 340    341       Chinstrap      Dream           0.435           18.1
# 341    342       Chinstrap      Dream           0.496           18.2
# 342    343       Chinstrap      Dream           0.508           19.0
# 343    344       Chinstrap      Dream           0.502           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# ...

# %% [markdown]
# <h1>5. groupby()</h1>

# %%
pandas_df
